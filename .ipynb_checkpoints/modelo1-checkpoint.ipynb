# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# --- MUDANÇA: Importar RandomForest ---
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import warnings
import time 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, classification_report


warnings.filterwarnings('ignore', category=UserWarning, module='xgboost')
warnings.filterwarnings('ignore', category=Warning) 

print("--- [Início do Pipeline (v55 - O Ensemble Heterogéneo de Elite)] ---")
print("A testar Stacking (XGB + LGBM + RF) baseado na Aula 5...")

# --- 1. FUNÇÃO DE PRÉ-PROCESSAMENTO (IDÊNTICA AO v16) ---

def formatar_celula(series_coluna):
    s = series_coluna.astype(str).replace('NULL', pd.NA)
    s = s.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
    s = s.str.upper()
    s = s.str.replace(r'[^A-Z0-9]+', '_', regex=True)
    s = s.str.strip('_')
    s = s.replace('', pd.NA)
    return s

def preprocessar_dados(df, colunas_scaler_treinadas=None, scaler=None):
    if 'RowId' not in df.columns and 'AVERAGE_SPEED_DIFF' not in df.columns:
        df_final_row_ids = np.arange(1, len(df) + 1)
    else:
        df_final_row_ids = None

    cols_to_transform = ['AVERAGE_CLOUDINESS', 'AVERAGE_RAIN']
    for col in cols_to_transform:
        if col in df.columns:
            df[col] = formatar_celula(df[col])

    cols_to_drop_base = ['city_name', 'AVERAGE_RAIN', 'AVERAGE_PRECIPITATION', 'record_date']
    
    try:
        df['record_date_dt'] = pd.to_datetime(df['record_date'], format='mixed', dayfirst=True)
        df['Hora_sin'] = np.sin(2 * np.pi * df['record_date_dt'].dt.hour/24)
        df['Hora_cos'] = np.cos(2 * np.pi * df['record_date_dt'].dt.hour/24)
        df['Mes_sin'] = np.sin(2 * np.pi * df['record_date_dt'].dt.month/12)
        df['Mes_cos'] = np.cos(2 * np.pi * df['record_date_dt'].dt.month/12)
        df['DIA_SEMANA'] = df['record_date_dt'].dt.dayofweek
        df['IS_WEEKEND'] = df['DIA_SEMANA'].isin([5, 6]).astype(int)
        rush_hours = [7, 8, 9, 17, 18, 19]
        df['IS_RUSH_HOUR'] = df['record_date_dt'].dt.hour.isin(rush_hours).astype(int)
        df = df.drop(columns=['record_date_dt'])
    except KeyError:
        pass

    cols_existentes_drop = [col for col in cols_to_drop_base if col in df.columns]
    df = df.drop(columns=cols_existentes_drop)

    if 'AVERAGE_CLOUDINESS' in df.columns:
        df['AVERAGE_CLOUDINESS'] = df['AVERAGE_CLOUDINESS'].replace('NAN', np.nan)
        df['AVERAGE_CLOUDINESS'] = df['AVERAGE_CLOUDINESS'].fillna('NONE')

    cols_to_onehot = ['LUMINOSITY', 'AVERAGE_CLOUDINESS', 'DIA_SEMANA']
    for col in cols_to_onehot:
        if col in df.columns:
            prefix = col[:3].upper()
            if col == 'DIA_SEMANA': prefix = 'DAY'
            dummies = pd.get_dummies(df[col], prefix=prefix, dtype=int, sparse=False)
            df = pd.concat([df, dummies], axis=1)
            df = df.drop(col, axis=1)

    cols_to_normalize = [
        'AVERAGE_FREE_FLOW_SPEED', 'AVERAGE_TIME_DIFF', 'AVERAGE_FREE_FLOW_TIME',
        'AVERAGE_TEMPERATURE', 'AVERAGE_ATMOSP_PRESSURE', 'AVERAGE_HUMIDITY',
        'AVERAGE_WIND_SPEED', 'IS_WEEKEND', 'IS_RUSH_HOUR',
        'Hora_sin', 'Hora_cos', 'Mes_sin', 'Mes_cos'
    ]
    cols_existentes_normalize = [col for col in cols_to_normalize if col in df.columns]
    
    if scaler is None:
        print("... (TREINO) A fitar o MinMaxScaler.")
        scaler = MinMaxScaler()
        if cols_existentes_normalize:
            df[cols_existentes_normalize] = scaler.fit_transform(df[cols_existentes_normalize])
        return df, scaler, cols_existentes_normalize, df_final_row_ids
    else:
        print("... (TESTE) A aplicar o MinMaxScaler já treinado.")
        cols_para_scaler_teste = [col for col in colunas_scaler_treinadas if col in df.columns]
        if cols_para_scaler_teste:
            df[cols_para_scaler_teste] = scaler.transform(df[cols_para_scaler_teste])
        return df, None, None, df_final_row_ids


# --- 2. CARREGAR DADOS ---
print("\n--- [Passo 1/7] A carregar dados de Treino e Teste... ---")
df_train = pd.read_csv("training_data.csv", delimiter=",", encoding="latin-1")
df_test = pd.read_csv("test_data.csv", delimiter=",", encoding="latin-1")
y_train_raw = df_train.pop('AVERAGE_SPEED_DIFF')
test_row_ids = np.arange(1, len(df_test) + 1)


# --- 3. PRÉ-PROCESSAMENTO (TREINO) ---
print("--- [Passo 2/7] A pré-processar dados de TREINO... ---")
X_train, scaler, colunas_scaler, _ = preprocessar_dados(df_train)
print("... (TREINO) A fitar o LabelEncoder.")
le = LabelEncoder()
y_train_formatado = formatar_celula(y_train_raw).replace('NAN', 'NONE').fillna('NONE')
y_train_encoded = le.fit_transform(y_train_formatado)
print(f"Classes do Alvo encontradas (em MAIÚSCULAS): {list(le.classes_)}")


# --- 4. PRÉ-PROCESSAMENTO (TESTE) ---
print("--- [Passo 3/7] A pré-processar dados de TESTE... ---")
X_test, _, _, _ = preprocessar_dados(df_test, colunas_scaler_treinadas=colunas_scaler, scaler=scaler)


# --- 5. ALINHAMENTO DE COLUNAS ---
print("--- [Passo 4/7] A alinhar colunas de Treino e Teste... ---")
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
X_train = X_train.reindex(columns=X_test.columns, fill_value=0)
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)
print(f"Shape final do Treino (X_train): {X_train.shape}")
print(f"Número de features: {X_train.shape[1]}") # 33


# --- 6. VALIDAÇÃO DO ENSEMBLE (Stacking v55) ---
print("\n--- [Passo 5/7] A configurar e validar o Stacking (XGB + LGBM + RF)... ---")

# Modelos de Base (Nível 0) 
estimators = [
    ('xgb', XGBClassifier(
        learning_rate=0.08, max_depth=5, n_estimators=100,
        subsample=0.7, colsample_bytree=0.9,
        use_label_encoder=False, eval_metric='mlogloss',
        random_state=42, n_jobs=-1
    )),
    ('lgbm', LGBMClassifier(
        subsample=0.9, num_leaves=50, n_estimators=200,
        learning_rate=0.01, colsample_bytree=0.8,
        random_state=42, n_jobs=-1, verbose=-1
    )),
    ('rf', RandomForestClassifier(
        n_estimators=100, 
        max_depth=10,      
        random_state=42, 
        n_jobs=-1
    ))
]

# Meta-Modelo (Nível 1) LR (v16)
meta_model = LogisticRegression(random_state=42, n_jobs=-1)

# Criar o Stack
stack_clf_final = StackingClassifier(
    estimators=estimators, 
    final_estimator=meta_model, 
    cv=5, 
    n_jobs=-1
)

print("A calcular o Cross-Validation do Stack (XGB + LGBM + RF)...")
start_time = time.time()
scores = cross_val_score(stack_clf_final, X_train, y_train_encoded, cv=5, scoring='accuracy', n_jobs=1, verbose=1)
end_time = time.time()

print(f"\nValidação concluída em {(end_time - start_time) / 60:.2f} minutos.")
print(f"Score ANTERIOR (v16, XGB+LGBM): 0.81489 (Kaggle: 0.83555)")
print(f"MELHOR ACCURACY (Stacking v55, XGB+LGBM+RF): {np.mean(scores):.5f}")


# --- 7. TREINO DO MODELO FINAL (STACKING v55) ---
print("\n--- [Passo 6/7] A treinar o modelo FINAL (Stacking v55)... ---")
stack_clf_final.fit(X_train, y_train_encoded)
print("... Modelo final treinado com sucesso!")


# --- 8. PREVISÃO E SUBMISSÃO ---
print("--- [Passo 7/7] A gerar previsões e a criar submission.csv... ---")
y_pred_encoded = stack_clf_final.predict(X_test)
y_pred_labels_upper = le.inverse_transform(y_pred_encoded)
y_pred_labels_final = pd.Series(y_pred_labels_upper).str.title()
print("... Labels convertidas para o formato 'Title Case' (ex: 'Medium')")

submission_df = pd.DataFrame({
    'RowId': test_row_ids,
    'Speed_Diff': y_pred_labels_final
})

submission_df.to_csv('submission_v55_HETERO_ELITE_STACK.csv', index=False)

print("\n--- [FIM DO PIPELINE] ---")
print("Ficheiro 'submission_v55_HETERO_ELITE_STACK.csv' criado com sucesso!")
print(submission_df.head())

print("\n" + "="*80)
print("   RELATÓRIO DETALHADO E VISUALIZAÇÃO (STACKING HETERO ELITE v55)")
print("="*80)

# 1. Gerar Previsões de Validação Cruzada
# Nota: Usamos o 'stack_clf_final' definido anteriormente
print("A gerar previsões via Cross-Validation (cv=5)...")
y_pred_cv = cross_val_predict(stack_clf_final, X_train, y_train_encoded, cv=5, n_jobs=-1)

# 2. Matriz de Confusão 
print("A desenhar a Matriz de Confusão...")
cm = confusion_matrix(y_train_encoded, y_pred_cv)
classes_nomes = list(le.classes_)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=classes_nomes, yticklabels=classes_nomes)
plt.title('Matriz de Confusão: Stacking Elite (Exp 55)')
plt.ylabel('Classe Real')
plt.xlabel('Classe Prevista')
plt.tight_layout()
plt.savefig('matriz_confusao_hetero_v55_laranja.png', dpi=300)
print("[SUCESSO] Imagem 'matriz_confusao_hetero_v55_laranja.png' guardada.")
# plt.show()

# 3. Relatório de Métricas (Formatado)
print("\n--- [1] Métricas de Classificação (Validação Cruzada) ---")
report_dict = classification_report(y_train_encoded, y_pred_cv, target_names=classes_nomes, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Formatação: Arredondar e limpar
df_report = df_report.round(3)
df_report['support'] = df_report['support'].astype(int)

# Imprimir alinhado à esquerda
print(df_report.to_string(justify='left'))

# 4. Tabela de Hiperparâmetros (Formatada)
print("\n--- [2] Tabela de Hiperparâmetros Utilizados ---")

params_data = [
    {"Modelo/Componente": "XGBoost (Nível 0)",     "Parâmetro": "learning_rate", "Valor": 0.08},
    {"Modelo/Componente": "XGBoost (Nível 0)",     "Parâmetro": "max_depth",     "Valor": 5},
    {"Modelo/Componente": "XGBoost (Nível 0)",     "Parâmetro": "n_estimators",  "Valor": 100},
    {"Modelo/Componente": "LightGBM (Nível 0)",    "Parâmetro": "learning_rate", "Valor": 0.01},
    {"Modelo/Componente": "LightGBM (Nível 0)",    "Parâmetro": "num_leaves",    "Valor": 50},
    {"Modelo/Componente": "RandomForest (Nível 0)", "Parâmetro": "n_estimators",  "Valor": 100},
    {"Modelo/Componente": "RandomForest (Nível 0)", "Parâmetro": "max_depth",     "Valor": 10},
    {"Modelo/Componente": "LogisticReg (Meta)",    "Parâmetro": "random_state",  "Valor": 42},
    {"Modelo/Componente": "StackingClassifier",    "Parâmetro": "cv (interno)",  "Valor": 5},
    {"Modelo/Componente": "Validação Global",      "Parâmetro": "Cross-Val (K)", "Valor": 5}
]

df_params = pd.DataFrame(params_data)

# Configurar pandas para mostrar tudo
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# Função para formatar e imprimir alinhado à esquerda
def imprimir_alinhado_esquerda(df):
    format_dict = {}
    for col in df.columns:
        if df[col].dtype == 'float64' or df[col].dtype == 'float32':
             df[col] = df[col].round(3)
    
    df_str = df.astype(str)
    return df_str.to_string(index=False, justify='left')

print(imprimir_alinhado_esquerda(df_params))

# 5. Exportar CSVs
df_report.to_csv('relatorio_metricas_hetero_v55_formatado.csv')
df_params.to_csv('tabela_hiperparametros_hetero_v55.csv', index=False)
print("\n[INFO] Tabelas exportadas para CSV.")
# Out:
# --- [Início do Pipeline (v55 - O Ensemble Heterogéneo de Elite)] ---
# A testar Stacking (XGB + LGBM + RF) baseado na Aula 5...
#
# --- [Passo 1/7] A carregar dados de Treino e Teste... ---
# --- [Passo 2/7] A pré-processar dados de TREINO... ---
# ... (TREINO) A fitar o MinMaxScaler.
# ... (TREINO) A fitar o LabelEncoder.
# Classes do Alvo encontradas (em MAIÚSCULAS): ['HIGH', 'LOW', 'MEDIUM', 'NONE', 'VERY_HIGH']
# --- [Passo 3/7] A pré-processar dados de TESTE... ---
# ... (TESTE) A aplicar o MinMaxScaler já treinado.
# --- [Passo 4/7] A alinhar colunas de Treino e Teste... ---
# Shape final do Treino (X_train): (6812, 33)
# Número de features: 33
#
# --- [Passo 5/7] A configurar e validar o Stacking (XGB + LGBM + RF)... ---
# A calcular o Cross-Validation do Stack (XGB + LGBM + RF)...
# [18:36:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:36:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:36:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:36:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:36:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:37:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:37:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:37:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:37:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:37:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:38:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:39:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:39:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:39:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:39:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:39:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.4min finished
# Validação concluída em 3.41 minutos.
# Score ANTERIOR (v16, XGB+LGBM): 0.81489 (Kaggle: 0.83555)
# MELHOR ACCURACY (Stacking v55, XGB+LGBM+RF): 0.81415
#
# --- [Passo 6/7] A treinar o modelo FINAL (Stacking v55)... ---
# [18:40:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
# ... Modelo final treinado com sucesso!
# --- [Passo 7/7] A gerar previsões e a criar submission.csv... ---
# ... Labels convertidas para o formato 'Title Case' (ex: 'Medium')
#
# --- [FIM DO PIPELINE] ---
# Ficheiro 'submission_v55_HETERO_ELITE_STACK.csv' criado com sucesso!
#    RowId Speed_Diff
# 0      1       None
# 1      2     Medium
# 2      3       None
# 3      4       High
# 4      5        Low
#
# ================================================================================
#    RELATÓRIO DETALHADO E VISUALIZAÇÃO (STACKING HETERO ELITE v55)
# ================================================================================
# A gerar previsões via Cross-Validation (cv=5)...
# [18:40:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:40:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:16] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:27] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# [18:41:28] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1758007651359/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
# A desenhar a Matriz de Confusão...
# [SUCESSO] Imagem 'matriz_confusao_hetero_v55_laranja.png' guardada.
#
# --- [1] Métricas de Classificação (Validação Cruzada) ---
#               precision  recall  f1-score  support
# HIGH          0.783      0.784   0.783     1063
# LOW           0.717      0.727   0.722     1419
# MEDIUM        0.790      0.786   0.788     1651
# NONE          0.898      0.907   0.902     2200
# VERY_HIGH     0.872      0.810   0.840      479
# accuracy      0.814      0.814   0.814        0
# macro avg     0.812      0.803   0.807     6812
# weighted avg  0.814      0.814   0.814     6812
#
# --- [2] Tabela de Hiperparâmetros Utilizados ---
# Modelo/Componente      Parâmetro     Valor
#      XGBoost (Nível 0) learning_rate  0.08
#      XGBoost (Nível 0)     max_depth   5.0
#      XGBoost (Nível 0)  n_estimators 100.0
#     LightGBM (Nível 0) learning_rate  0.01
#     LightGBM (Nível 0)    num_leaves  50.0
# RandomForest (Nível 0)  n_estimators 100.0
# RandomForest (Nível 0)     max_depth  10.0
#     LogisticReg (Meta)  random_state  42.0
#     StackingClassifier  cv (interno)   5.0
#       Validação Global Cross-Val (K)   5.0
#
# [INFO] Tabelas exportadas para CSV.
